# %% [markdown]
# Connection and Data Import

# %%
pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in c:\users\imezh\anaconda3\lib\site-packages (2.9.10)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import psycopg2

path = "C:/Users/imezh/Downloads/workbench/customers.csv"
df = pd.read_csv(path)

conn = psycopg2.connect(
    host="localhost",
    dbname="playroom",
    user="postgres",
    password="Veroni4ka!"
)
# Out:
#    id first_name last_name           email  country
# 0   1       Anna   Mueller  user1@mail.com  Germany
# 1   2       John     Smith  user2@mail.com      USA
# 2   3      Marie    Dubois  user3@mail.com   France
# 3   4       Ivan    Ivanov  user4@mail.com   Russia
# 4   5       Lena     Klein  user5@mail.com  Germany

# %%
import matplotlib.pyplot as plt

# Загрузка данных
df = pd.read_sql('SELECT name, price FROM products', con=conn)

# Построение гистограммы цен
plt.figure(figsize=(10,6))
plt.bar(df['name'], df['price'], color='skyblue')
plt.xlabel('Product')
plt.ylabel('Price')
plt.title('Product Prices')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\imezh\anaconda3\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
